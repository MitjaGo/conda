# %% [markdown]
# <a href="https://colab.research.google.com/github/MitjaGo/conda/blob/main/E4P_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %% [markdown]
# <div style="clear: both;">
#   <div style="float: right; margin-right 1em;">
#     <img src="https://www.sava-hotels-resorts.com/si/files/default/grafika/novi/Sava-Hotels-&-Resorts_prim_pozitiv.jpg" alt="">
#   </div>
#   <div>
#       <h2><b>EXPORT</b>4PHOBS</h2>
#     <p>Generator csv datoteke za vnos BAR cenikov v Phobs.</p>
#   </div>
# </div>

# %% [markdown]
# ---

# %% [markdown]
# <a class="btn btn-success" href="https://docs.google.com/spreadsheets/d/1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g/edit#gid=520644704" target="_blank">YIELD TABELICA</a>
# <br>
# <a class="btn btn-success" href="https://drive.google.com/drive/folders/1n9ROsfPIOgG9o6HClAwWmMWtXpkCMttG" target="_blank">EXPORT4Phobs-Mapa</a>
# <br>

# %%
#@title
import ipywidgets as widgets

a1 = widgets.Button(description="GH Bernardin", layout=widgets.Layout(width="33%"))
a2 = widgets.Button(description="Hotel Histrion", layout=widgets.Layout(width="33%"))
a3 = widgets.Button(description="Hotel Vile Park", layout=widgets.Layout(width="33%"))
a4 = widgets.Button(description="Hotel Salinera", layout=widgets.Layout(width="33%"))
a5 = widgets.Button(description="Apartmaji Salinera", layout=widgets.Layout(width="33%"))
a6 = widgets.Button(description="Vila Maia", layout=widgets.Layout(width="33%"))
a7 = widgets.Button(description="Hotel Haliaetum", layout=widgets.Layout(width="33%"))
a8 = widgets.Button(description="Hotel Mirta", layout=widgets.Layout(width="33%"))
a9 = widgets.Button(description="Depandanse San Simon", layout=widgets.Layout(width="33%"))
 
h1 = widgets.HBox(children=[a1,a2,a3])
h1

h2 = widgets.HBox(children=[a4,a5,a6])
h2

h3 = widgets.HBox(children=[a7,a8,a9])
h3

h4 = widgets.VBox(children=[h1,h2,h3])
h4

from IPython.display import display
output = widgets.Output()
display(h4, output)

def on_button_clicked(b):
    with output:
        print("CSV file za GH Bernardin je ustvarjen. ")
        #df5.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\GHB-4-Phobs.csv', index=None, header=None)
        df5 = pd.concat([df, df2, df3, df4], axis=0).to_csv('Export-Phobs-GHB.csv', index=False, header=False)
        # !cp Export-Phobs-GHB.csv "drive/My Drive/EXPORT4PHOBS"
a1.on_click(on_button_clicked)

def on_button_clicked(b):
    with output:
        print("CSV file za Hotel Histrion je ustvarjen. ")
        #df10.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HH-4-Phobs.csv', index=None, header=None)
        df10 = pd.concat([df6, df7, df8, df9], axis=0).to_csv('Export-Phobs-HH.csv', index=False, header=False)
        # !cp Export-Phobs-HH.csv "drive/My Drive/EXPORT4PHOBS"
a2.on_click(on_button_clicked)

def on_button_clicked(b):
    with output:
        print("CSV file za Hotel Vile Park je ustvarjen. ")
        #df15.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HVP-4-Phobs.csv', index=None, header=None)
        df15 = pd.concat([df11, df12, df13, df14], axis=0).to_csv('Export-Phobs-HVP.csv', index=False, header=False)
        # !cp Export-Phobs-HVP.csv "drive/My Drive/EXPORT4PHOBS"
a3.on_click(on_button_clicked)

def on_button_clicked(b):
    with output:
        print("CSV file za Hotel Salinera je ustvarjen. ")
        #df20.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HSALINERA-4-Phobs.csv', index=None, header=None)
        df20 = pd.concat([df16, df17, df18, df19], axis=0).to_csv('Export-Phobs-HSalinera.csv', index=False, header=False)
        # !cp Export-Phobs-HSalinera.csv "drive/My Drive/EXPORT4PHOBS"
a4.on_click(on_button_clicked)

def on_button_clicked(b):
    with output:
        print("CSV file za Apartmaje Salinera je ustvarjen. ")
        #df25.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\APPSALINERA-4-Phobs.csv', index=None, header=None)
        df25 = pd.concat([df21, df22, df23, df24], axis=0).to_csv('Export-Phobs-App-Salinera.csv', index=False, header=False)
        # !cp Export-Phobs-App-Salinera.csv "drive/My Drive/EXPORT4PHOBS"
a5.on_click(on_button_clicked)

def on_button_clicked(b):
    with output:
        print("CSV file za Vilo Maia je ustvarjen. ")
        #df30.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\VILAMAIA-4-Phobs.csv', index=None, header=None)
        df30 = pd.concat([df26, df27, df28, df29], axis=0).to_csv('Export-Phobs-Vila-Maia.csv', index=False, header=False)
        # !cp Export-Phobs-Vila-Maia.csv "drive/My Drive/EXPORT4PHOBS"
a6.on_click(on_button_clicked)



def on_button_clicked(b):
    with output:
        print("CSV file za Hotel Haliaetum je ustvarjen. ")
        #df35.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HALIAETUM-4-Phobs.csv', index=None, header=None)
        df35 = pd.concat([df31, df32, df33, df34], axis=0).to_csv('Export-Phobs-Haliaetum.csv', index=False, header=False)
        # !cp Export-Phobs-Haliaetum.csv "drive/My Drive/EXPORT4PHOBS"
a7.on_click(on_button_clicked)

def on_button_clicked(b):
    with output:
        print("CSV file za Hotel Mirta je ustvarjen. ")
        #df40.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\MIRTA-4-Phobs.csv', index=None, header=None)
        df40 = pd.concat([df36, df37, df38, df39], axis=0).to_csv('Export-Phobs-Mirta.csv', index=False, header=False)
        # !cp Export-Phobs-Mirta.csv "drive/My Drive/EXPORT4PHOBS"
a8.on_click(on_button_clicked)

def on_button_clicked(b):
    with output:
        print("CSV file za Depandanse San Simon je ustvarjen. ")
        #df45.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\DEPANDANSE_SSR-4-Phobs.csv', index=None, header=None)
        df45 = pd.concat([df41, df42, df43, df44], axis=0).to_csv('Export-Phobs-Depandanse-ssr.csv', index=False, header=False)
        # !cp Export-Phobs-Depandanse-ssr.csv "drive/My Drive/EXPORT4PHOBS"
a9.on_click(on_button_clicked)
# Out:
# ...
# Output()

# %% [markdown]
# ----

# %%
#@title

import pandas as pd

############nov df1 LOS 1 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "GHBERNARDIN"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df['1night'] = df['1night'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df['GHB'] = 61000
df.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df['nicla'] = 0
df.head()

######################

#MIN STAY iz PHOBSA , LOS 1

import numpy as np
df['LOS1'] = 4792
df.head()

########################

df['LOS1'] = df['LOS1'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena1noc = ['GHB','Date','nicla','1night','LOS1']
df = df.reindex(columns=vrstice_imena1noc)

############nov df2 LOS 2 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "GHBERNARDIN"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df2 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df2['2nights'] = df2['2nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df2['GHB'] = 61000
df2.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df2['nicla'] = 0
df2.head()

######################

#MIN STAY iz PHOBSA , LOS 2, 

import numpy as np
df2['LOS2'] = 4788
df2.head()

########################

df2['LOS2'] = df2['LOS2'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena2noc = ['GHB','Date','nicla','2nights','LOS2']
df2 = df2.reindex(columns=vrstice_imena2noc)


###koda štima###

############nov df3 LOS 3 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!1

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "GHBERNARDIN"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df3 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df3['3nights'] = df3['3nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df3['GHB'] = 61000
df3.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df3['nicla'] = 0
df3.head()

######################

#MIN STAY iz PHOBSA , LOS 3, 

import numpy as np
df3['LOS3'] = 4793
df3.head()

########################

df3['LOS3'] = df3['LOS3'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena3noc = ['GHB','Date','nicla','3nights','LOS3']
df3 = df3.reindex(columns=vrstice_imena3noc)


############nov df4 LOS 4 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "GHBERNARDIN"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df4 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df4['4nights'] = df4['4nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df4['GHB'] = 61000
df4.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df4['nicla'] = 0
df4.head()

######################

#MIN STAY iz PHOBSA , LOS 4, 

import numpy as np
df4['LOS4'] = 4794
df4.head()

########################

df4['LOS4'] = df4['LOS4'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena4noci = ['GHB','Date','nicla','4nights','LOS4']
df4 = df4.reindex(columns=vrstice_imena4noci)

df.columns = ['GHB','Date','nicla','nights','LOS']
df2.columns = ['GHB','Date','nicla','nights','LOS']
df3.columns = ['GHB','Date','nicla','nights','LOS']
df4.columns = ['GHB','Date','nicla','nights','LOS']

#print(df.to_string(index=False, header=True))
#print(df2.to_string(index=False, header=True))
#print(df3.to_string(index=False, header=True))
#print(df4.to_string(index=False, header=True))

#df.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\GHB.csv', index = False, header=False)
#df2.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\GHB2.csv', index = False, header=False)
#df3.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\GHB3.csv', index = False, header=False)
#df4.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\GHB4.csv', index = False, header=False)

#pd.concat([
#pd.concat([df, df2, df3, df4], axis=0)]).to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\GHB-4-Phobs.csv', index=None, header=None)
             
#df5 = pd.concat([df, df2, df3, df4], axis=0)

# %%
#@title
 # **Histrion** df6, df7, df8, df9 in concat df 10

# %%
#@title
import pandas as pd

############nov df1 LOS 1 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "HISTRION"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df6 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df6['1night'] = df6['1night'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df6['HH'] = 61100
df6.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df6['nicla'] = 0
df6.head()

######################

#MIN STAY iz PHOBSA , LOS 1

import numpy as np
df6['LOS1'] = 4960
df6.head()

########################

df6['LOS1'] = df6['LOS1'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena1noc = ['HH','Date','nicla','1night','LOS1']
df6 = df6.reindex(columns=vrstice_imena1noc)

############nov df2 LOS 2 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "HISTRION"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df7 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df7['2nights'] = df7['2nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df7['HH'] = 61100
df7.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df7['nicla'] = 0
df7.head()

######################

#MIN STAY iz PHOBSA , LOS 2, 

import numpy as np
df7['LOS2'] = 7850
df7.head()

########################

df7['LOS2'] = df7['LOS2'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena2noc = ['HH','Date','nicla','2nights','LOS2']
df7 = df7.reindex(columns=vrstice_imena2noc)


###koda štima###

############nov df3 LOS 3 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!1

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "HISTRION"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df8 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df8['3nights'] = df8['3nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df8['HH'] = 61100
df8.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df8['nicla'] = 0
df8.head()

######################

#MIN STAY iz PHOBSA , LOS 3, 

import numpy as np
df8['LOS3'] = 7852
df8.head()

########################

df8['LOS3'] = df8['LOS3'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena3noc = ['HH','Date','nicla','3nights','LOS3']
df8 = df8.reindex(columns=vrstice_imena3noc)


############nov df4 LOS 4 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "HISTRION"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df9 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df9['4nights'] = df9['4nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df9['HH'] = 61100
df9.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df9['nicla'] = 0
df9.head()

######################

#MIN STAY iz PHOBSA , LOS 4, 

import numpy as np
df9['LOS4'] = 7854
df9.head()

########################

df9['LOS4'] = df9['LOS4'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena4noci = ['HH','Date','nicla','4nights','LOS4']
df9 = df9.reindex(columns=vrstice_imena4noci)

df6.columns = ['HH','Date','nicla','nights','LOS']
df7.columns = ['HH','Date','nicla','nights','LOS']
df8.columns = ['HH','Date','nicla','nights','LOS']
df9.columns = ['HH','Date','nicla','nights','LOS']

#print(df6.to_string(index=False, header=True))
#print(df7.to_string(index=False, header=True))
#print(df8.to_string(index=False, header=True))
#print(df9.to_string(index=False, header=True))

#df6.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HH1.csv', index = False, header=False)
#df7.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HH2.csv', index = False, header=False)
#df8.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HH3.csv', index = False, header=False)
#df9.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HH4.csv', index = False, header=False)

#pd.concat([
#pd.concat([df6, df7, df8, df9], axis=0)]).to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HH-4-Phobs.csv', index=None, header=None)
                                                     
                                                     
#df10 = pd.concat([df6, df7, df8, df9], axis=0)

# %%
#@title
 # **Hotel Vile Park** df11, df12, df13, df14 in concat df 15

# %%
#@title
import pandas as pd

############nov df1 LOS 1 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "VILE"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df11 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df11['1night'] = df11['1night'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df11['HVP'] = 61200
df11.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df11['nicla'] = 0
df11.head()

######################

#MIN STAY iz PHOBSA , LOS 1

import numpy as np
df11['LOS1'] = 5023
df11.head()

########################

df11['LOS1'] = df11['LOS1'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena1noc = ['HVP','Date','nicla','1night','LOS1']
df11 = df11.reindex(columns=vrstice_imena1noc)

############nov df2 LOS 2 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "VILE"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df12 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df12['2nights'] = df12['2nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df12['HVP'] = 61200
df12.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df12['nicla'] = 0
df12.head()

######################

#MIN STAY iz PHOBSA , LOS 2, 

import numpy as np
df12['LOS2'] = 5024
df12.head()

########################

df12['LOS2'] = df12['LOS2'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena2noc = ['HVP','Date','nicla','2nights','LOS2']
df12 = df12.reindex(columns=vrstice_imena2noc)


###koda štima###

############nov df3 LOS 3 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!1

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "VILE"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df13 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df13['3nights'] = df13['3nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df13['HVP'] = 61200
df13.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df13['nicla'] = 0
df13.head()

######################

#MIN STAY iz PHOBSA , LOS 3, 

import numpy as np
df13['LOS3'] = 5025
df13.head()

########################

df13['LOS3'] = df13['LOS3'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena3noc = ['HVP','Date','nicla','3nights','LOS3']
df13 = df13.reindex(columns=vrstice_imena3noc)


############nov df4 LOS 4 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "VILE"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df14 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df14['4nights'] = df14['4nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df14['HVP'] = 61200
df14.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df14['nicla'] = 0
df14.head()

######################

#MIN STAY iz PHOBSA , LOS 4, 

import numpy as np
df14['LOS4'] = 5026
df14.head()

########################

df14['LOS4'] = df14['LOS4'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena4noci = ['HVP','Date','nicla','4nights','LOS4']
df14 = df14.reindex(columns=vrstice_imena4noci)

df11.columns = ['HVP','Date','nicla','nights','LOS']
df12.columns = ['HVP','Date','nicla','nights','LOS']
df13.columns = ['HVP','Date','nicla','nights','LOS']
df14.columns = ['HVP','Date','nicla','nights','LOS']

#print(df11.to_string(index=False, header=True))
#print(df12.to_string(index=False, header=True))
#print(df13.to_string(index=False, header=True))
#print(df14.to_string(index=False, header=True))

#df11.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HH1.csv', index = False, header=False)
#df12.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HH2.csv', index = False, header=False)
#df13.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HH3.csv', index = False, header=False)
#df14.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HH4.csv', index = False, header=False)

#pd.concat([
#pd.concat([df11, df12, df13, df14], axis=0)]).to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HVP-4-Phobs.csv', index=None, header=None)
                                                     
                                                     
#df15 = pd.concat([df11, df12, df13, df14], axis=0)

# %%
#@title
 # **Hotel SALINERA** df16, df17, df18, df19 in concat df 20

# %%
#@title
import pandas as pd

############nov df1 LOS 1 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "HSALINERA"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df16 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df16['1night'] = df16['1night'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df16['HSAL'] = 62000
df16.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df16['nicla'] = 0
df16.head()

######################

#MIN STAY iz PHOBSA , LOS 1

import numpy as np
df16['LOS1'] = 5100
df16.head()

########################

df16['LOS1'] = df16['LOS1'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena1noc = ['HSAL','Date','nicla','1night','LOS1']
df16 = df16.reindex(columns=vrstice_imena1noc)

############nov df2 LOS 2 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "HSALINERA"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df17 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df17['2nights'] = df17['2nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df17['HSAL'] = 62000
df17.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df17['nicla'] = 0
df17.head()

######################

#MIN STAY iz PHOBSA , LOS 2, 

import numpy as np
df17['LOS2'] = 5101
df17.head()

########################

df17['LOS2'] = df17['LOS2'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena2noc = ['HSAL','Date','nicla','2nights','LOS2']
df17 = df17.reindex(columns=vrstice_imena2noc)


###koda štima###

############nov df3 LOS 3 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!1

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "HSALINERA"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df18 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df18['3nights'] = df18['3nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df18['HSAL'] = 62000
df18.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df18['nicla'] = 0
df18.head()

######################

#MIN STAY iz PHOBSA , LOS 3, 

import numpy as np
df18['LOS3'] = 5102
df18.head()

########################

df18['LOS3'] = df18['LOS3'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena3noc = ['HSAL','Date','nicla','3nights','LOS3']
df18 = df18.reindex(columns=vrstice_imena3noc)


############nov df4 LOS 4 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "HSALINERA"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df19 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df19['4nights'] = df19['4nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df19['HSAL'] = 62000
df19.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df19['nicla'] = 0
df19.head()

######################

#MIN STAY iz PHOBSA , LOS 4, 

import numpy as np
df19['LOS4'] = 7875
df19.head()

########################

df19['LOS4'] = df19['LOS4'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena4noci = ['HSAL','Date','nicla','4nights','LOS4']
df19 = df19.reindex(columns=vrstice_imena4noci)

df16.columns = ['HSAL','Date','nicla','nights','LOS']
df17.columns = ['HSAL','Date','nicla','nights','LOS']
df18.columns = ['HSAL','Date','nicla','nights','LOS']
df19.columns = ['HSAL','Date','nicla','nights','LOS']

#print(df16.to_string(index=False, header=True))
#print(df17.to_string(index=False, header=True))
#print(df18.to_string(index=False, header=True))
#print(df19.to_string(index=False, header=True))

#df16.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HSAL1.csv', index = False, header=False)
#df17.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HSAL2.csv', index = False, header=False)
#df18.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HSAL3.csv', index = False, header=False)
#df19.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HSAL4.csv', index = False, header=False)

#pd.concat([
#pd.concat([df16, df17, df18, df19], axis=0)]).to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HSALINERA-4-Phobs.csv', index=None, header=None)
                                                     
                                                     
#df20 = pd.concat([df16, df17, df18, df19], axis=0)

# %%
#@title
#Apartmaji salinera df 21,22,23,24 in df 25 

import pandas as pd

############nov df1 LOS 1 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "APPSALINERA"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df21 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df21['1night'] = df21['1night'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df21['APSAL'] = 620200
df21.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df21['nicla'] = 0
df21.head()

######################

#MIN STAY iz PHOBSA , LOS 1

import numpy as np
df21['LOS1'] = 5123
df21.head()

########################

df21['LOS1'] = df21['LOS1'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena1noc = ['APSAL','Date','nicla','1night','LOS1']
df21 = df21.reindex(columns=vrstice_imena1noc)

############nov df2 LOS 2 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "APPSALINERA"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df22 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df22['2nights'] = df22['2nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df22['APSAL'] = 620200
df22.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df22['nicla'] = 0
df22.head()

######################

#MIN STAY iz PHOBSA , LOS 2, 

import numpy as np
df22['LOS2'] = 5124
df22.head()

########################

df22['LOS2'] = df22['LOS2'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena2noc = ['APSAL','Date','nicla','2nights','LOS2']
df22 = df22.reindex(columns=vrstice_imena2noc)


###koda štima###

############nov df3 LOS 3 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!1

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "APPSALINERA"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df23 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df23['3nights'] = df23['3nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df23['APSAL'] = 620200
df23.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df23['nicla'] = 0
df23.head()

######################

#MIN STAY iz PHOBSA , LOS 3, 

import numpy as np
df23['LOS3'] = 5125
df23.head()

########################

df23['LOS3'] = df23['LOS3'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena3noc = ['APSAL','Date','nicla','3nights','LOS3']
df23 = df23.reindex(columns=vrstice_imena3noc)


############nov df4 LOS 4 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "APPSALINERA"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df24 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df24['4nights'] = df24['4nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df24['APSAL'] = 620200
df24.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df24['nicla'] = 0
df24.head()

######################

#MIN STAY iz PHOBSA , LOS 4, 

import numpy as np
df24['LOS4'] = 5126
df24.head()

########################

df24['LOS4'] = df24['LOS4'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena4noci = ['APSAL','Date','nicla','4nights','LOS4']
df24 = df24.reindex(columns=vrstice_imena4noci)

df21.columns = ['APSAL','Date','nicla','nights','LOS']
df22.columns = ['APSAL','Date','nicla','nights','LOS']
df23.columns = ['APSAL','Date','nicla','nights','LOS']
df24.columns = ['APSAL','Date','nicla','nights','LOS']

#print(df21.to_string(index=False, header=True))
#print(df22.to_string(index=False, header=True))
#print(df23.to_string(index=False, header=True))
#print(df24.to_string(index=False, header=True))

#df21.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\APPSAL1.csv', index = False, header=False)
#df22.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\APPSAL2.csv', index = False, header=False)
#df23.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\APPSAL3.csv', index = False, header=False)
#df24.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\APPSAL4.csv', index = False, header=False)

#pd.concat([
#pd.concat([df21, df22, df23, df24], axis=0)]).to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\APPSALINERA-4-Phobs.csv', index=None, header=None)
                                                     
                                                     
#df25 = pd.concat([df21, df22, df23, df24], axis=0)

# %%
#@title
#Apartmaji MAIA df 26,27,28,29 in df 30 

import pandas as pd

############nov df1 LOS 1 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "VMAIA"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df26 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df26['1night'] = df26['1night'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df26['MAIA'] = 622000
df26.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df26['nicla'] = 0
df26.head()

######################

#MIN STAY iz PHOBSA , LOS 1

import numpy as np
df26['LOS1'] = 5111
df26.head()

########################

df26['LOS1'] = df26['LOS1'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena1noc = ['MAIA','Date','nicla','1night','LOS1']
df26 = df26.reindex(columns=vrstice_imena1noc)

############nov df2 LOS 2 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "VMAIA"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df27 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df27['2nights'] = df27['2nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df27['MAIA'] = 622000
df27.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df27['nicla'] = 0
df27.head()

######################

#MIN STAY iz PHOBSA , LOS 2, 

import numpy as np
df27['LOS2'] = 5112
df27.head()

########################

df27['LOS2'] = df27['LOS2'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena2noc = ['MAIA','Date','nicla','2nights','LOS2']
df27 = df27.reindex(columns=vrstice_imena2noc)


###koda štima###

############nov df3 LOS 3 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!1

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "VMAIA"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df28 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df28['3nights'] = df28['3nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df28['MAIA'] = 622000
df28.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df28['nicla'] = 0
df28.head()

######################

#MIN STAY iz PHOBSA , LOS 3, 

import numpy as np
df28['LOS3'] = 5113
df28.head()

########################

df28['LOS3'] = df28['LOS3'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena3noc = ['MAIA','Date','nicla','3nights','LOS3']
df28 = df28.reindex(columns=vrstice_imena3noc)


############nov df4 LOS 4 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "VMAIA"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df29 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df29['4nights'] = df29['4nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df29['MAIA'] = 622000
df29.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df29['nicla'] = 0
df29.head()

######################

#MIN STAY iz PHOBSA , LOS 4, 

import numpy as np
df29['LOS4'] = 5114
df29.head()

########################

df29['LOS4'] = df29['LOS4'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena4noci = ['MAIA','Date','nicla','4nights','LOS4']
df29 = df29.reindex(columns=vrstice_imena4noci)

df26.columns = ['MAIA','Date','nicla','nights','LOS']
df27.columns = ['MAIA','Date','nicla','nights','LOS']
df28.columns = ['MAIA','Date','nicla','nights','LOS']
df29.columns = ['MAIA','Date','nicla','nights','LOS']

#print(df26.to_string(index=False, header=True))
#print(df27.to_string(index=False, header=True))
#print(df28.to_string(index=False, header=True))
#print(df29.to_string(index=False, header=True))

#df26.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\VILAMAIA1.csv', index = False, header=False)
#df27.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\VILAMAIA2.csv', index = False, header=False)
#df28.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\VILAMAIA3.csv', index = False, header=False)
#df29.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\VILAMAIA4.csv', index = False, header=False)

#pd.concat([
#pd.concat([df26, df27, df28, df29], axis=0)]).to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\VILAMAIA-4-Phobs.csv', index=None, header=None)
                                                     
                                                     
#df30 = pd.concat([df26, df27, df28, df29], axis=0)

# %%
#@title
#Haliaetum df 31,32,33,34 in df 35 

import pandas as pd

############nov df1 LOS 1 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "HALIAETUM"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df31 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df31['1night'] = df31['1night'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df31['HAL'] = 630100
df31.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df31['nicla'] = 0
df31.head()

######################

#MIN STAY iz PHOBSA , LOS 1

import numpy as np
df31['LOS1'] = 5360
df31.head()

########################

df31['LOS1'] = df31['LOS1'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena1noc = ['HAL','Date','nicla','1night','LOS1']
df31 = df31.reindex(columns=vrstice_imena1noc)

############nov df2 LOS 2 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "HALIAETUM"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df32 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df32['2nights'] = df32['2nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df32['HAL'] = 630100
df32.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df32['nicla'] = 0
df32.head()

######################

#MIN STAY iz PHOBSA , LOS 2, 

import numpy as np
df32['LOS2'] = 7857
df32.head()

########################

df32['LOS2'] = df32['LOS2'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena2noc = ['HAL','Date','nicla','2nights','LOS2']
df32 = df32.reindex(columns=vrstice_imena2noc)


###koda štima###

############nov df3 LOS 3 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!1

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "HALIAETUM"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df33 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df33['3nights'] = df33['3nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df33['HAL'] = 630100
df33.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df33['nicla'] = 0
df33.head()

######################

#MIN STAY iz PHOBSA , LOS 3, 

import numpy as np
df33['LOS3'] = 7859
df33.head()

########################

df33['LOS3'] = df33['LOS3'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena3noc = ['HAL','Date','nicla','3nights','LOS3']
df33 = df33.reindex(columns=vrstice_imena3noc)


############nov df4 LOS 4 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "HALIAETUM"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df34 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df34['4nights'] = df34['4nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df34['HAL'] = 630100
df34.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df34['nicla'] = 0
df34.head()

######################

#MIN STAY iz PHOBSA , LOS 4, 

import numpy as np
df34['LOS4'] = 7861
df34.head()

########################

df34['LOS4'] = df34['LOS4'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena4noci = ['HAL','Date','nicla','4nights','LOS4']
df34 = df34.reindex(columns=vrstice_imena4noci)

df31.columns = ['HAL','Date','nicla','nights','LOS']
df32.columns = ['HAL','Date','nicla','nights','LOS']
df33.columns = ['HAL','Date','nicla','nights','LOS']
df34.columns = ['HAL','Date','nicla','nights','LOS']

#print(df31.to_string(index=False, header=True))
#print(df32.to_string(index=False, header=True))
#print(df33.to_string(index=False, header=True))
#print(df34.to_string(index=False, header=True))

#df31.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\VILAMAIA1.csv', index = False, header=False)
#df32.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\VILAMAIA2.csv', index = False, header=False)
#df33.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\VILAMAIA3.csv', index = False, header=False)
#df34.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\VILAMAIA4.csv', index = False, header=False)

#pd.concat([
#pd.concat([df31, df32, df33, df34], axis=0)]).to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\HALIAETUM-4-Phobs.csv', index=None, header=None)
                                                     
                                                     
#df35 = pd.concat([df31, df32, df33, df34], axis=0)

# %%
#@title
#MIRTA df 36,37,38,39 in df 40 

import pandas as pd

############nov df1 LOS 1 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "MIRTA"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df36 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df36['1night'] = df36['1night'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df36['MIRT'] = 630000
df36.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df36['nicla'] = 0
df36.head()

######################

#MIN STAY iz PHOBSA , LOS 1

import numpy as np
df36['LOS1'] = 5139
df36.head()

########################

df36['LOS1'] = df36['LOS1'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena1noc = ['MIRT','Date','nicla','1night','LOS1']
df36 = df36.reindex(columns=vrstice_imena1noc)

############nov df2 LOS 2 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "MIRTA"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df37 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df37['2nights'] = df37['2nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df37['MIRT'] = 630000
df37.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df37['nicla'] = 0
df37.head()

######################

#MIN STAY iz PHOBSA , LOS 2, 

import numpy as np
df37['LOS2'] = 7885
df37.head()

########################

df37['LOS2'] = df37['LOS2'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena2noc = ['MIRT','Date','nicla','2nights','LOS2']
df37 = df37.reindex(columns=vrstice_imena2noc)


###koda štima###

############nov df3 LOS 3 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!1

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "MIRTA"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df38 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df38['3nights'] = df38['3nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df38['MIRT'] = 630000
df38.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df38['nicla'] = 0
df38.head()

######################

#MIN STAY iz PHOBSA , LOS 3, 

import numpy as np
df38['LOS3'] = 7887
df38.head()

########################

df38['LOS3'] = df38['LOS3'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena3noc = ['MIRT','Date','nicla','3nights','LOS3']
df38 = df38.reindex(columns=vrstice_imena3noc)


############nov df4 LOS 4 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "MIRTA"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df39 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df39['4nights'] = df39['4nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df39['MIRT'] = 630000
df39.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df39['nicla'] = 0
df39.head()

######################

#MIN STAY iz PHOBSA , LOS 4, 

import numpy as np
df39['LOS4'] = 7889
df39.head()

########################

df39['LOS4'] = df39['LOS4'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena4noci = ['MIRT','Date','nicla','4nights','LOS4']
df39 = df39.reindex(columns=vrstice_imena4noci)

df36.columns = ['MIRT','Date','nicla','nights','LOS']
df37.columns = ['MIRT','Date','nicla','nights','LOS']
df38.columns = ['MIRT','Date','nicla','nights','LOS']
df39.columns = ['MIRT','Date','nicla','nights','LOS']

#print(df36.to_string(index=False, header=True))
#print(df37.to_string(index=False, header=True))
#print(df38.to_string(index=False, header=True))
#print(df39.to_string(index=False, header=True))

#df36.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\VILAMAIA1.csv', index = False, header=False)
#df37.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\VILAMAIA2.csv', index = False, header=False)
#df38.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\VILAMAIA3.csv', index = False, header=False)
#df39.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\VILAMAIA4.csv', index = False, header=False)

#pd.concat([
#pd.concat([df36, df37, df38, df39], axis=0)]).to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\MIRTA-4-Phobs.csv', index=None, header=None)
                                                                                                          
#df40 = pd.concat([df36, df37, df38, df39], axis=0)

# %%
#@title
#DEPSSR df 41,42,43,44 in df 45 

import pandas as pd

############nov df1 LOS 1 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "DEPSSR"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df41 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df41['1night'] = df41['1night'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df41['DEP'] = 630400
df41.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df41['nicla'] = 0
df41.head()

######################

#MIN STAY iz PHOBSA , LOS 1

import numpy as np
df41['LOS1'] = 5135
df41.head()

########################

df41['LOS1'] = df41['LOS1'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena1noc = ['DEP','Date','nicla','1night','LOS1']
df41 = df41.reindex(columns=vrstice_imena1noc)

############nov df2 LOS 2 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "DEPSSR"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df42 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df42['2nights'] = df42['2nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df42['DEP'] = 630400
df42.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df42['nicla'] = 0
df42.head()

######################

#MIN STAY iz PHOBSA , LOS 2, 

import numpy as np
df42['LOS2'] = 7904
df42.head()

########################

df42['LOS2'] = df42['LOS2'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena2noc = ['DEP','Date','nicla','2nights','LOS2']
df42 = df42.reindex(columns=vrstice_imena2noc)


###koda štima###

############nov df3 LOS 3 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!1

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "DEPSSR"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df43 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df43['3nights'] = df43['3nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df43['DEP'] = 630400
df43.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df43['nicla'] = 0
df43.head()

######################

#MIN STAY iz PHOBSA , LOS 3, 

import numpy as np
df43['LOS3'] = 7906
df43.head()

########################

df43['LOS3'] = df43['LOS3'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena3noc = ['DEP','Date','nicla','3nights','LOS3']
df43 = df43.reindex(columns=vrstice_imena3noc)


############nov df4 LOS 4 ###################!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

gsheetid = "1zeM0nH_VmEdoY_SONBnUFXCF7XXbLufHo6sqRFJw5-g"
sheet_name = "DEPSSR"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

gsheet_url

df44 = pd.read_csv(gsheet_url)

#string BAR, ki se doda k številki v celici

df44['4nights'] = df44['4nights'].apply(lambda x: f"BAR{x}")

#####################################

#Številka hotela, ki se doda v vrstico

import numpy as np
df44['DEP'] = 630400
df44.head()

####################################

#Številka, ki jo zahteva PHOBS

import numpy as np
df44['nicla'] = 0
df44.head()

######################

#MIN STAY iz PHOBSA , LOS 4, 

import numpy as np
df44['LOS4'] = 7908
df44.head()

########################

df44['LOS4'] = df44['LOS4'].apply(lambda x: f"YIELD{x}")

#vrstni red tabelice- heading
vrstice_imena4noci = ['DEP','Date','nicla','4nights','LOS4']
df44 = df44.reindex(columns=vrstice_imena4noci)

df41.columns = ['DEP','Date','nicla','nights','LOS']
df42.columns = ['DEP','Date','nicla','nights','LOS']
df43.columns = ['DEP','Date','nicla','nights','LOS']
df44.columns = ['DEP','Date','nicla','nights','LOS']

#print(df41.to_string(index=False, header=True))
#print(df42.to_string(index=False, header=True))
#print(df43.to_string(index=False, header=True))
#print(df44.to_string(index=False, header=True))

#df41.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\DEPSSR1.csv', index = False, header=False)
#df42.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\DEPSSR2.csv', index = False, header=False)
#df43.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\DEPSSR3.csv', index = False, header=False)
#df44.to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\DEPSSR4.csv', index = False, header=False)

#pd.concat([
#pd.concat([df41, df42, df43, df44], axis=0)]).to_csv (r'C:\Users\Uporabnik\Desktop\PHOBS\NEW\DEPANDANSESSR-4-Phobs.csv', index=None, header=None)
                                                                                                          
#df45 = pd.concat([df41, df42, df43, df44], axis=0)
